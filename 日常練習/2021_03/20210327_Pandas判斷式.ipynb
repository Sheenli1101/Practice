# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('googleplaystore.csv', encoding='utf_8_sig')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10040 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.1+ MB

# %%
df.loc[:, 'Rating'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838     True
# 10839    False
# 10840    False
# Name: Rating, Length: 10841, dtype: bool

# %%
null_df = df.loc[df.loc[:, 'Rating'].isnull(), :]

# %%
null_df.loc[null_df.loc[:,'Category']=='BEAUTY']
# Out:
#                                       App Category  Rating  Reviews  \
# 113             Wrinkles and rejuvenation   BEAUTY     NaN    182.0
# 123                Manicure - nail design   BEAUTY     NaN    119.0
# 126          Skin Care and Natural Beauty   BEAUTY     NaN    654.0
# 129   Secrets of beauty, youth and health   BEAUTY     NaN     77.0
# 130    Recipes and tips for losing weight   BEAUTY     NaN     35.0
# 134         Lady adviser (beauty, health)   BEAUTY     NaN     30.0
# 5998                   Aura Hair Group BC   BEAUTY     NaN      0.0
# 6318            BJ Grand Salon Mobile App   BEAUTY     NaN      1.0
# 6828                      BU Beauty Rooms   BEAUTY     NaN      1.0
# 7460          Calvin Klein Petite Dresses   BEAUTY     NaN      0.0
# 8505                 DK Studio Barbershop   BEAUTY     NaN      8.0
#
#                     Size  Installs  Type  Price Content Rating  Genres  \
# 113                 5.7M  100000.0  Free    0.0   Everyone 10+  Beauty
# ...

# %%
null_df.loc[null_df.loc[:,'Category']=='BEAUTY',:].describe()
# Out:
#        Rating     Reviews       Installs  Price
# count     0.0   11.000000      11.000000   11.0
# mean      NaN  100.636364   25531.818182    0.0
# std       NaN  192.799519   39534.379170    0.0
# min       NaN    0.000000      50.000000    0.0
# 25%       NaN    1.000000     100.000000    0.0
# 50%       NaN   30.000000   10000.000000    0.0
# 75%       NaN   98.000000   30000.000000    0.0
# max       NaN  654.000000  100000.000000    0.0

# %%
null = df[df['Rating'].isnull()]

# %%
null[null['Category']=='BEAUTY']['Size']
# Out:
# 113                   5.7M
# 123                   3.7M
# 126                   7.4M
# 129                   2.9M
# 130                   3.1M
# 134                   9.9M
# 5998    Varies with device
# 6318                   15M
# 6828                  6.0M
# 7460                  3.7M
# 8505                   17M
# Name: Size, dtype: object

# %%
rating_mean = df['Rating'].mean()

# %%
null
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#        Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %%
null['Rating'].fillna(rating_mean)
# Out:
# 23       4.193338
# 113      4.193338
# 123      4.193338
# 126      4.193338
# 129      4.193338
#            ...
# 10824    4.193338
# 10825    4.193338
# 10831    4.193338
# 10835    4.193338
# 10838    4.193338
# Name: Rating, Length: 1474, dtype: float64

# %%
null_1 = null.copy()
null_1.loc[:,'Rating'] = null['Rating'].fillna(rating_mean)

# %%
null_1
# Out:
#                                        App             Category    Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN  4.193338
# 113              Wrinkles and rejuvenation               BEAUTY  4.193338
# 123                 Manicure - nail design               BEAUTY  4.193338
# 126           Skin Care and Natural Beauty               BEAUTY  4.193338
# 129    Secrets of beauty, youth and health               BEAUTY  4.193338
# ...                                    ...                  ...       ...
# 10824                            Cardio-FR              MEDICAL  4.193338
# 10825                   Naruto & Boruto FR               SOCIAL  4.193338
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION  4.193338
# 10835                             FR Forms             BUSINESS  4.193338
# 10838               Parkinson Exercices FR              MEDICAL  4.193338
#
#        Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %%
df_2 = df.copy()

# %%
df_2[df_2['Rating'].isnull()].dropna(how='')
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#        Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %%
df2 = df.dropna(how='any')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8715 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8715 non-null   object
#  1   Category        8715 non-null   object
#  2   Rating          8715 non-null   float64
#  3   Reviews         8715 non-null   float64
#  4   Size            8715 non-null   object
#  5   Installs        8715 non-null   float64
#  6   Type            8715 non-null   object
#  7   Price           8715 non-null   float64
#  8   Content Rating  8715 non-null   object
#  9   Genres          8715 non-null   object
#  10  Last Updated    8715 non-null   object
#  11  Current Ver     8715 non-null   object
#  12  Android Ver     8715 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 953.2+ KB

# %%
df3 = df.copy()

# %%
index = df3[df3['Rating'].isnull()].index

# %%
df3 = df3.drop(index, axis=0)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9367 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9367 non-null   object
#  1   Category        9367 non-null   object
#  2   Rating          9367 non-null   float64
#  3   Reviews         9366 non-null   float64
#  4   Size            9367 non-null   object
#  5   Installs        9366 non-null   float64
#  6   Type            9367 non-null   object
#  7   Price           8719 non-null   float64
#  8   Content Rating  9366 non-null   object
#  9   Genres          9367 non-null   object
#  10  Last Updated    9366 non-null   object
#  11  Current Ver     9363 non-null   object
#  12  Android Ver     9364 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 1.0+ MB
