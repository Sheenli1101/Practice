# %%
import pandas as pd

# %%
oecd = pd.read_excel('OECDoutlook2019.xls', header=4, skipfooter=1, index_col=0, na_values=['NC', 'NAN'])

# %%
oecd
# Out:
#                          Unnamed: 1 Unnamed: 2    Q1-2001    Q2-2001  \
# Time
# Country                        Unit        NaN        NaN        NaN
# Australia       Percentage, 2016-17          i   7.284177   0.586820
# Austria            Percentage, 2010          i   1.753404   1.843686
# Belgium            Percentage, 2016          i  -0.564691   6.291900
# Canada             Percentage, 2012          i   3.939644  -0.058260
# Chile              Percentage, 2013          i   0.418974   6.542847
# Estonia            Percentage, 2010          i  -1.292546  10.955903
# Finland            Percentage, 2010          i   8.441849   0.726557
# France             Percentage, 2014          i   1.643698   2.462088
# Germany            Percentage, 2010          i   2.794677   0.904227
# Greece             Percentage, 2010          i   8.277442   5.053384
# Hungary            Percentage, 2005          i  13.429390  20.502837
# ...

# %%
oecd2 = oecd.copy().loc[:, 'Q1-2001':].apply(lambda col: col.fillna(col.mean()))

# %%
oecd2.apply(lambda col: col.apply(lambda x: (x-col.mean())/col.std()))
# Out:
#                      Q1-2001       Q2-2001   Q3-2001       Q4-2001  \
# Time
# Country        -9.492027e-17  1.638527e-16  0.000000  1.072687e-16
# Australia       7.687031e-01 -7.512996e-01  0.569914 -1.668067e-01
# Austria        -4.134525e-01 -5.194307e-01 -0.116408  1.877443e-01
# Belgium        -9.089254e-01  3.011834e-01 -0.114064 -8.435154e-02
# Canada          5.383781e-02 -8.703050e-01 -1.512078 -1.228978e+00
# Chile          -6.986754e-01  3.474786e-01  1.229322  1.547932e-01
# Estonia        -1.064498e+00  1.161607e+00  0.802445  1.681977e+00
# Finland         1.016146e+00 -7.255207e-01 -0.277273 -5.488493e-01
# France         -4.369011e-01 -4.053470e-01  0.051606  6.396170e-02
# Germany        -1.908891e-01 -6.927437e-01  0.192955  1.614512e-01
# Greece          9.810050e-01  7.269979e-02  0.499144  1.230207e-01
# Hungary         2.082190e+00  2.922841e+00  0.726818 -7.142584e-01
# Iceland         8.107556e-01  3.676316e+00  1.956279  1.583344e+00
# ...
